# %% [markdown]
# <a href="https://colab.research.google.com/github/rijosudu123/ict-assessment/blob/main/casestudy_preprocessinng.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
house_price = pd.read_csv("/content/House_Pricing.csv")
house_price.head()
# Out:
#            ID Date House was Sold  Sale Price  No of Bedrooms  \
# 0  7129300520     14 October 2017    221900.0               3
# 1  6414100192    14 December 2017    538000.0               3
# 2  5631500400    15 February 2016    180000.0               2
# 3  2487200875    14 December 2017    604000.0               4
# 4  1954400510    15 February 2016    510000.0               3
#
#    No of Bathrooms  Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors  \
# 0             1.00               1180.0              5650.0           1.0
# 1             2.25               2570.0              7242.0           2.0
# 2             1.00                770.0             10000.0           1.0
# 3             3.00               1960.0              5000.0           1.0
# 4             2.00               1680.0              8080.0           1.0
#
#   Waterfront View No of Times Visited  ... Overall Grade  \
# 0              No                 NaN  ...             7
# ...

# %%
house_price.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 21608    False
# 21609    False
# 21610    False
# 21611    False
# 21612    False
# Length: 21613, dtype: bool

# %%
house_price.dtypes
# Out:
# ID                                             int64
# Date House was Sold                           object
# Sale Price                                   float64
# No of Bedrooms                                 int64
# No of Bathrooms                              float64
# Flat Area (in Sqft)                          float64
# Lot Area (in Sqft)                           float64
# No of Floors                                 float64
# Waterfront View                               object
# No of Times Visited                           object
# Condition of the House                        object
# Overall Grade                                  int64
# Area of the House from Basement (in Sqft)    float64
# Basement Area (in Sqft)                        int64
# Age of House (in Years)                        int64
# Renovated Year                                 int64
# Zipcode                                      float64
# Latitude                                     float64
# ...

# %%
house_price.isna().sum()
# Out:
# ID                                               0
# Date House was Sold                              0
# Sale Price                                       4
# No of Bedrooms                                   0
# No of Bathrooms                                  4
# Flat Area (in Sqft)                              9
# Lot Area (in Sqft)                               9
# No of Floors                                     0
# Waterfront View                                  0
# No of Times Visited                          19489
# Condition of the House                           0
# Overall Grade                                    0
# Area of the House from Basement (in Sqft)        3
# Basement Area (in Sqft)                          0
# Age of House (in Years)                          0
# Renovated Year                                   0
# Zipcode                                          1
# Latitude                                         1
# ...

# %%
house_price.drop(columns  = ['No of Times Visited','Latitude','Longitude','Date House was Sold'],inplace=True)
house_price
# Out:
#                ID  Sale Price  No of Bedrooms  No of Bathrooms  \
# 0      7129300520    221900.0               3             1.00
# 1      6414100192    538000.0               3             2.25
# 2      5631500400    180000.0               2             1.00
# 3      2487200875    604000.0               4             3.00
# 4      1954400510    510000.0               3             2.00
# ...           ...         ...             ...              ...
# 21608   263000018    360000.0               3             2.50
# 21609  6600060120    400000.0               4             2.50
# 21610  1523300141    402101.0               2             0.75
# 21611   291310100    400000.0               3             2.50
# 21612  1523300157    325000.0               2             0.75
#
#        Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors Waterfront View  \
# 0                   1180.0              5650.0           1.0              No
# ...

# %%
columns= ['Sale Price','No of Bathrooms','Flat Area (in Sqft)','Lot Area (in Sqft)','Area of the House from Basement (in Sqft)','Zipcode','Living Area after Renovation (in Sqft)']
for i in columns:
  house_price[i] = house_price[i].fillna(house_price[i].median())

# %%
house_price
# Out:
#                ID  Sale Price  No of Bedrooms  No of Bathrooms  \
# 0      7129300520    221900.0               3             1.00
# 1      6414100192    538000.0               3             2.25
# 2      5631500400    180000.0               2             1.00
# 3      2487200875    604000.0               4             3.00
# 4      1954400510    510000.0               3             2.00
# ...           ...         ...             ...              ...
# 21608   263000018    360000.0               3             2.50
# 21609  6600060120    400000.0               4             2.50
# 21610  1523300141    402101.0               2             0.75
# 21611   291310100    400000.0               3             2.50
# 21612  1523300157    325000.0               2             0.75
#
#        Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors Waterfront View  \
# 0                   1180.0              5650.0           1.0              No
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# %%
label_enc = LabelEncoder()
house_price['Waterfront View'] = label_enc.fit_transform(house_price['Waterfront View'])
house_price
# Out:
#                ID  Sale Price  No of Bedrooms  No of Bathrooms  \
# 0      7129300520    221900.0               3             1.00
# 1      6414100192    538000.0               3             2.25
# 2      5631500400    180000.0               2             1.00
# 3      2487200875    604000.0               4             3.00
# 4      1954400510    510000.0               3             2.00
# ...           ...         ...             ...              ...
# 21608   263000018    360000.0               3             2.50
# 21609  6600060120    400000.0               4             2.50
# 21610  1523300141    402101.0               2             0.75
# 21611   291310100    400000.0               3             2.50
# 21612  1523300157    325000.0               2             0.75
#
#        Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors  Waterfront View  \
# 0                   1180.0              5650.0           1.0                0
# ...

# %%
label_enc = LabelEncoder()
house_price['Condition of the House'] = label_enc.fit_transform(house_price['Condition of the House'])
house_price
# Out:
#                ID  Sale Price  No of Bedrooms  No of Bathrooms  \
# 0      7129300520    221900.0               3             1.00
# 1      6414100192    538000.0               3             2.25
# 2      5631500400    180000.0               2             1.00
# 3      2487200875    604000.0               4             3.00
# 4      1954400510    510000.0               3             2.00
# ...           ...         ...             ...              ...
# 21608   263000018    360000.0               3             2.50
# 21609  6600060120    400000.0               4             2.50
# 21610  1523300141    402101.0               2             0.75
# 21611   291310100    400000.0               3             2.50
# 21612  1523300157    325000.0               2             0.75
#
#        Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors  Waterfront View  \
# 0                   1180.0              5650.0           1.0                0
# ...

# %%
house_price.dtypes
# Out:
# ID                                             int64
# Sale Price                                   float64
# No of Bedrooms                                 int64
# No of Bathrooms                              float64
# Flat Area (in Sqft)                          float64
# Lot Area (in Sqft)                           float64
# No of Floors                                 float64
# Waterfront View                                int64
# Condition of the House                         int64
# Overall Grade                                  int64
# Area of the House from Basement (in Sqft)    float64
# Basement Area (in Sqft)                        int64
# Age of House (in Years)                        int64
# Renovated Year                                 int64
# Zipcode                                      float64
# Living Area after Renovation (in Sqft)       float64
# Lot Area after Renovation (in Sqft)            int64
# dtype: object

# %%
sns.histplot(house_price['Sale Price'],kde=True)
plt.title("Price For The House")
plt.show()

# %%
sns.histplot(house_price['Flat Area (in Sqft)'],kde=True)
plt.title('Flat Area')
plt.show()

# %%
sns.histplot(house_price['Age of House (in Years)'],kde=True)
plt.title("Age Of House")
plt.show()

# %%
sns.histplot(house_price['Area of the House from Basement (in Sqft)'],kde=True)
plt.title("Area Of Basement ")
plt.show()

# %%
sns.histplot(house_price['Living Area after Renovation (in Sqft)'],kde=True)
plt.title("Renovation")
plt.show()

# %%
columns = ['Sale Price','Flat Area (in Sqft)','Age of House (in Years)','Area of the House from Basement (in Sqft)','Living Area after Renovation (in Sqft)']
for i in columns:
           plt.figure(figsize=(5,5))
           plt.boxplot(house_price[i])
           plt.title(i)
           plt.show()

# %%
q1=house_price["Sale Price"].quantile(.25)
q3=house_price["Sale Price"].quantile(.75)
iqr=q3-q1
lower=q1-iqr*1.5
upper=q3+iqr*1.5
print(f"\nq1:{q1},\nq3:{q3},\niqr:{iqr},\nlower:{lower},\nupper:{upper}")
# Out:
# q1:322000.0,
# q3:645000.0,
# iqr:323000.0,
# lower:-162500.0,
# upper:1129500.0

# %%
house_price["Sale Price"] = house_price["Sale Price"].clip(lower=lower,upper=upper)
plt.boxplot(house_price["Sale Price"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x790b59953710>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x790b59950a70>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x790b59951b50>],
#  'medians': [<matplotlib.lines.Line2D at 0x790b599520f0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x790b59950890>],
#  'means': []}

# %%
q1 = house_price["Flat Area (in Sqft)"].quantile(.25)
q3 = house_price["Flat Area (in Sqft)"].quantile(.75)
iqr = q3-q1
lower = q1-iqr*1.5
upper = q3+iqr*1.5
print(f"\nq1:{q1},\nq3:{q3},\niqr:{iqr},\nlower:{lower},\nupper:{upper}")
# Out:
# q1:1430.0,
# q3:2550.0,
# iqr:1120.0,
# lower:-250.0,
# upper:4230.0

# %%
house_price["Flat Area (in Sqft)"] = house_price['Flat Area (in Sqft)'].clip(lower=lower,upper=upper)
plt.boxplot(house_price['Flat Area (in Sqft)'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x790b599d5fa0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x790b599d6570>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x790b599d5ca0>],
#  'medians': [<matplotlib.lines.Line2D at 0x790b599d6a20>],
#  'fliers': [<matplotlib.lines.Line2D at 0x790b599d6cf0>],
#  'means': []}

# %%
q1 = house_price["Area of the House from Basement (in Sqft)"].quantile(.25)
q3 = house_price['Area of the House from Basement (in Sqft)'].quantile(.75)
iqr = q3-q1
lower = q3-iqr*1.5
upper = q1+iqr*1.5
print(f"\nq1:{q1},\nq3:{q3},\niqr:{iqr}\nlower:{lower},\nupper:{upper}")
# Out:
# q1:1190.0,
# q3:2210.0,
# iqr:1020.0
# lower:680.0,
# upper:2720.0

# %%
house_price['Area of the House from Basement (in Sqft)'] = house_price['Area of the House from Basement (in Sqft)'].clip(lower=lower,upper=upper)
plt.boxplot(house_price['Area of the House from Basement (in Sqft)'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x790b59834ce0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x790b59836390>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x790b59835d30>],
#  'medians': [<matplotlib.lines.Line2D at 0x790b59836960>],
#  'fliers': [<matplotlib.lines.Line2D at 0x790b59836c00>],
#  'means': []}

# %%
q1 = house_price["Living Area after Renovation (in Sqft)"].quantile(.25)
q3 = house_price['Living Area after Renovation (in Sqft)'].quantile(.75)
iqr = q3-q1
lower = q3-iqr*1.5
upper = q1+iqr*1.5
print(f"\nq1:{q1},\nq3:{q3},\niqr:{iqr}\nlower:{lower},\nupper:{upper}")
# Out:
# q1:1490.0,
# q3:2360.0,
# iqr:870.0
# lower:1055.0,
# upper:2795.0

# %%
house_price['Living Area after Renovation (in Sqft)'] = house_price['Living Area after Renovation (in Sqft)'].clip(lower=lower,upper=upper)
plt.boxplot(house_price['Living Area after Renovation (in Sqft)'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x790b59896540>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x790b59896b40>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x790b59896240>],
#  'medians': [<matplotlib.lines.Line2D at 0x790b598970b0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x790b59897200>],
#  'means': []}

# %%
y = house_price["Sale Price"]
x = house_price.drop(columns = ['Sale Price'])

# %%
x.columns
# Out:
# Index(['ID', 'No of Bedrooms', 'No of Bathrooms', 'Flat Area (in Sqft)',
#        'Lot Area (in Sqft)', 'No of Floors', 'Waterfront View',
#        'Condition of the House', 'Overall Grade',
#        'Area of the House from Basement (in Sqft)', 'Basement Area (in Sqft)',
#        'Age of House (in Years)', 'Renovated Year', 'Zipcode',
#        'Living Area after Renovation (in Sqft)',
#        'Lot Area after Renovation (in Sqft)'],
#       dtype='object')

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.preprocessing import StandardScaler,MinMaxScaler,MaxAbsScaler

# %%
std_scaler = StandardScaler()
minmax_scaler = MinMaxScaler()
x_train['Age of House (in Years)'] = std_scaler.fit_transform(x_train[['Age of House (in Years)']])
x_test['Age of House (in Years)'] = std_scaler.fit_transform(x_test[['Age of House (in Years)']])


x_train['Flat Area (in Sqft)'] = minmax_scaler.fit_transform(x_train[['Flat Area (in Sqft)']])
x_test['Flat Area (in Sqft)'] = minmax_scaler.fit_transform(x_test[['Flat Area (in Sqft)']])


x_train['Area of the House from Basement (in Sqft)'] = minmax_scaler.fit_transform(x_train[['Area of the House from Basement (in Sqft)']])
x_test['Area of the House from Basement (in Sqft)'] = minmax_scaler.fit_transform(x_test[['Area of the House from Basement (in Sqft)']])


x_train['Living Area after Renovation (in Sqft)'] = minmax_scaler.fit_transform(x_train[['Living Area after Renovation (in Sqft)']])
x_test['Living Area after Renovation (in Sqft)'] = minmax_scaler.fit_transform(x_test[['Living Area after Renovation (in Sqft)']])


x_train.head()
# Out:
#                ID  No of Bedrooms  No of Bathrooms  Flat Area (in Sqft)  \
# 6325   5467910190               3             1.75             0.378173
# 13473  9331800580               2             1.00             0.180203
# 17614  2407000405               3             1.00             0.200508
# 16970  5466700290               3             2.25             0.456853
# 20868  3026059361               2             2.50             0.368274
#
#        Lot Area (in Sqft)  No of Floors  Waterfront View  \
# 6325              13095.0           1.0                0
# 13473              3700.0           1.0                0
# 17614              7486.0           1.5                0
# 16970              7500.0           1.0                0
# 20868              1439.0           2.0                0
#
#        Condition of the House  Overall Grade  \
# 6325                        3              9
# 13473                       2              6
# 17614                       2              6
# ...
